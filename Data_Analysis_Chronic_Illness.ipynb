# %% [markdown]
# # Data_Analysis
#
# Questions:
#
# - Does X treatment affect Y symptom positively/negatively/not at all? What are the most strongly-correlated symptoms and treatments?
# - Are there subsets within our current diagnoses that could more accurately represent symptoms and predict effective treatments?
# - Can we reliably predict what triggers a flare for a given user or all users with a certain condition?
# - Could we recommend treatments more effectively based on similarity of users, rather than specific symptoms and conditions? (Netflix recommendations for treatments)
# - Can we quantify a patient’s level of disease activity based on their symptoms? How different is it from our existing measures?
# - Can we predict which symptom should be treated to have the greatest effect on a given illness?
# - How accurately can we guess a condition based on a user’s symptoms?
# - Can we detect new interactions between treatments?
#
# <a href="https://www.kaggle.com/flaredown/flaredown-autoimmune-symptom-tracker?select=export.csv">Source</a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Chunna\Documents\Data_Analyst_Portfolio\Chronic_Illness\Chronic_Illness.csv', low_memory=False)
df
# Out:
#                                   user_id   age     sex country checkin_date  \
# 0        QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1        QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4        QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# ...                                   ...   ...     ...     ...          ...
# 7976218  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976219  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976220  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976221  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
# 7976222  QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==  22.0  female      GB   2019-12-04
#
#         trackable_id trackable_type  \
# 0               1069      Condition
# 1               1069      Condition
# 2               3168      Condition
# 3               3169      Condition
# 4               3170      Condition
# ...              ...            ...
# 7976218            1            Tag
# 7976219            2            Tag
# 7976220         9002           Food
# 7976221         9139           Food
# 7976222        10260           Food
#
#                                             trackable_name trackable_value
# 0                                       Ulcerative colitis               0
# 1                                       Ulcerative colitis               0
# 2        pain in left upper arm felt like i was getting...               4
# 3                                  hip pain when gettin up               3
# 4                                      pain in hand joints               4
# ...                                                    ...             ...
# 7976218                                              tired             NaN
# 7976219                                           stressed             NaN
# 7976220                                               soup             NaN
# 7976221                                             yogurt             NaN
# 7976222                                            granola             NaN
#
# [7976223 rows x 9 columns]

# %%
# Check for Nulls
null_count = df.isnull().sum().sum()
null_count
# Out:
# 1666202

# %%
# Count rows
row_count = df.shape[0]
row_count
# Out:
# 7976223

# %%
# Percentage of nulls
round(null_count/row_count * 100,2)
# Out:
# 20.89

# %%
# Case deletion
df.dropna()
df.sample(5)
# Out:
#                                   user_id   age         sex country  \
# 2846526  QEVuQwEAQQ3ad6+Yz7a7qu5MgGd8/w==  40.0      female      US
# 3185704  QEVuQwEAnZmjZgZjRqV7rHnJsIn3Hg==  21.0  doesnt_say      GB
# 3713564  QEVuQwEAmudAnVOr31mxzTwu7H4/zA==  21.0      female      US
# 6709026  QEVuQwEANsxIbSg0M10KHWTMvK0NWQ==  36.0      female      US
# 69284    QEVuQwEAwSdAon7QCJUAUcdkUDK/5g==  33.0       other      GB
#
#         checkin_date trackable_id trackable_type    trackable_name  \
# 2846526   2018-07-30         5676      Treatment         Metformin
# 3185704   2018-09-24          397      Condition      Fibromyalgia
# 3713564   2019-01-10         2055      Condition  Stomach problems
# 6709026   2019-11-04       219825        Weather              icon
# 69284     2015-07-01          145        Symptom       Muscle pain
#
#         trackable_value
# 2846526       250mg qhs
# 3185704               3
# 3713564               3
# 6709026       clear-day
# 69284                 3

# %%
# Unique values in each column
for col in df:
    print(df[col].unique())
# Out:
# ['QEVuQwEABlEzkh7fsBBjEe26RyIVcg==' 'QEVuQwEAWRNGnuTRqXG2996KSkTIEw=='
#  'QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==' ... 'QEVuQwEAe+Me/lpz+GEjbH7bMu3UeA=='
#  'QEVuQwEA/3ZnJPHdtLiOWBy1VAYIYA==' 'QEVuQwEAtlfm8VyoxZ9biWjDHb74gQ==']
# [         nan  3.20000e+01  2.00000e+00  3.10000e+01  2.90000e+01
#   3.30000e+01  3.70000e+01  2.40000e+01  4.20000e+01  4.50000e+01
#   3.40000e+01  4.70000e+01  2.50000e+01  1.18000e+02  4.60000e+01
#   5.10000e+01  3.80000e+01  4.40000e+01  6.20000e+01  2.00000e+01
#   7.60000e+01  5.00000e+01  5.30000e+01  3.00000e+01  5.60000e+01
#   3.50000e+01  2.20000e+01  6.30000e+01  5.80000e+01  2.30000e+01
#   4.30000e+01  1.90000e+01  2.80000e+01  3.90000e+01  4.10000e+01
#   5.50000e+01  6.50000e+01  2.70000e+01  3.60000e+01  4.80000e+01
#   2.10000e+01  6.40000e+01  6.00000e+01  5.90000e+01  9.00000e+01
#   2.60000e+01  7.00000e+01  5.40000e+01  6.90000e+01  4.00000e+01
#   7.40000e+01  1.70000e+01  6.60000e+01  4.90000e+01  1.80000e+01
#   7.10000e+01  3.00000e+00  7.80000e+01  6.10000e+01  5.70000e+01
#   5.20000e+01 -4.30000e+01  6.80000e+01  6.70000e+01  1.60000e+01
#   7.20000e+01  1.00000e+01  6.00000e+00  0.00000e+00  5.00000e+00
#  -1.99630e+04  9.00000e+00  7.90000e+01  7.00000e+00  8.00000e+00
#  -1.96691e+05  4.00000e+00  1.94200e+03  8.00000e+01  1.30000e+01
#   1.00000e+00  1.40000e+01  1.50000e+01  1.10000e+01  1.20000e+01
#   8.10000e+01 -3.30000e+01  7.30000e+01  2.01800e+03  2.19000e+02
#   8.29000e+02  7.85000e+02  7.50000e+01  7.70000e+01  3.61000e+02
#   8.50000e+01  8.70000e+01  9.80000e+01  9.90000e+01  8.60000e+01
#  -3.00000e+01]
# [nan 'male' 'female' 'other' 'doesnt_say']
# [nan 'US' 'CA' 'GB' 'MO' 'CL' 'SE' 'NL' 'AU' 'ZA' 'IE' 'BE' 'FI' 'NZ' 'KZ'
#  'AT' 'PE' 'IN' 'CH' 'PT' 'ES' 'IL' 'DE' 'SG' 'IS' 'UA' 'HK' 'RU' 'NO'
#  'FR' 'AS' 'DK' 'UY' 'MU' 'DZ' 'PK' 'AR' 'AF' 'TH' 'LU' 'SA' 'JP' 'MV'
#  'PL' 'UM' 'MY' 'DO' 'CZ' 'IT' 'CO' 'MA' 'MX' 'PR' 'QA' 'WS' 'RO' 'LY'
#  'AE' 'BR' 'HU' 'AG' 'LT' 'IR' 'AD' 'SV' 'VN' 'GR' 'KR' 'ME' 'RS' 'AL'
#  'SK' 'BY' 'CI' 'SI' 'CR' 'MG' 'PF' 'PH' 'TZ' 'ZW' 'GT' 'EE' 'ST' 'HR'
#  'VI' 'BH' 'TV' 'BM' 'AX' 'BN' 'AQ' 'BF' 'BS' 'EC' 'LB' 'KE' 'NG' 'PG'
#  'TR' 'SX' 'NP' 'BT' 'ID' 'TT' 'UG' 'ZM' 'KW' 'IM' 'GE' 'EG' 'CY' 'BD'
#  'VU' 'BB' 'GH' 'TW' 'LV' 'LR' 'PA' 'HN' 'SC' 'VE' 'KH' 'IQ' 'SD' 'GY'
#  'CN' 'MT' 'ET' 'UZ' 'BG' 'LK' 'JO' 'NI' 'BQ' 'MK' 'JE' 'CU' 'JM' 'TF'
#  'FK' 'CV' 'SO' 'HT' 'GI' 'BW' 'BA' 'RE' 'KY' 'VG' 'LC' 'SZ' 'IO' 'AW'
#  'FO' 'GD' 'YE' 'GG' 'MD' 'OM' 'PY' 'TN' 'GP' 'BZ']
# ['2015-11-26' '2017-04-28' '2015-06-22' ... '2019-08-19' '2019-08-12'
#  '2019-12-06']
# ['1069' '3168' '3169' ... '222282' '222574' '225818']
# ['Condition' 'Symptom' 'Weather' 'Treatment' 'Tag' 'Food' 'HBI']
# ['Ulcerative colitis'
#  'pain in left upper arm felt like i was getting a shot'
#  'hip pain when gettin up' ... 'chicken pizza for 1' 'turkey fillets'
#  'poor productivity']
# ['0' '4' '3' ... '10mg + 1mL' 'tried predilisone' '1 patch (12 hours)']

# %% [markdown]
# ### Does X treatment affect Y symptom positively/negatively/not at all? What are the most strongly-correlated symptoms and treatments?

# %%
symptom = df['trackable_type']=='Symptom'
treatment = df['trackable_type']=='Treatment'
df_corr = df[symptom]
df_corr = pd.pivot_table(
                        df_corr,
                        values='trackable_value',
                        index=['user_id','age','sex','country'],
                        columns='trackable_type'
                        )
                                
                        
df_corr
#plt.matshow(df_corr.corr())
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-15-99167ec4fc58> in <module>
#       2 treatment = df['trackable_type']=='Treatment'
#       3 df_corr = df[symptom]
# ----> 4 df_corr = pd.pivot_table(
#       5                         df_corr,
#       6                         values='trackable_value',
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      99
#     100     grouped = data.groupby(keys, observed=observed)
# --> 101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     103         agged = agged.dropna(how="all")
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     938         func = _maybe_mangle_lambdas(func)
#     939
# --> 940         result, how = self._aggregate(func, *args, **kwargs)
#     941         if how is None:
#     942             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     318
#     319         if isinstance(arg, str):
# --> 320             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     321
#     322         if isinstance(arg, dict):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     274         if f is not None:
#     275             if callable(f):
# --> 276                 return f(*args, **kwargs)
#     277
#     278             # people may try to aggregate on a non-callable attribute
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1229         """
#    1230         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
# -> 1231         return self._cython_agg_general(
#    1232             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1233         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1001         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1002     ) -> DataFrame:
# -> 1003         agg_blocks, agg_items = self._cython_agg_blocks(
#    1004             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1005         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1103
#    1104         if not (agg_blocks or split_frames):
# -> 1105             raise DataError("No numeric types to aggregate")
#    1106
#    1107         if split_items:
#
# DataError: No numeric types to aggregate
